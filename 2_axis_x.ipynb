# %%
import pandas as pd

# %%
import os, platform, time, urllib.request, openpyxl, operator
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from openpyxl import Workbook
import sys, requests, re, json
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
table_1 = pd.read_csv(r'official_influencers.csv')
table_1
# Out:
#     ranking               username                 alias  \
# 0         1         @gessicakayane         gessicakayane
# 1         2         @andressasuita         andressasuita
# 2         3              @leonardo              leonardo
# 3         4                 @taina                 taina
# 4         5               @cocielo               cocielo
# 5         6          @jujusalimeni          jujusalimeni
# 6         7                  @lexa                  lexa
# 7         8       @flaviapavanelli       flaviapavanelli
# 8         9        @luvadepedreiro        luvadepedreiro
# 9        10                 @kjapa                 kjapa
# 10       11         @camilaqueiroz         camilaqueiroz
# 11       12             @marimaria             marimaria
# 12       13            @rafaavitti            rafaavitti
# 13       14        @zefelipecantor        zefelipecantor
# 14       15            @caiocastro            caiocastro
# 15       16               @mirella               mirella
# 16       17             @tirullipa             tirullipa
# 17       18  @fernandasouzaoficial  fernandasouzaoficial
# 18       19        @brunogagliasso        brunogagliasso
# 19       20         @pefabiodemelo         pefabiodemelo
# 20       21          @rafakalimann          rafakalimann
# 21       22              @viihtube              viihtube
# 22       23             @gioewbank             gioewbank
# 23       24               @kevinho               kevinho
# 24       25              @juliette              juliette
# 25       26              @virginia              virginia
# 26       27        @larissamanoela        larissamanoela
# 27       28           @tatawerneck           tatawerneck
# 28       29      @whinderssonnunes      whinderssonnunes
# 29       30                @anitta                anitta
#
#                                            categories  engagement  followers
# 0          ['Humor', 'Celebrities', 'Animals & Pets']        2.00       15.2
# 1   ['Modeling', 'Celebrities', 'Animals & Pets', ...        2.19       15.7
# 2                                           ['Music']        1.00       15.9
# 3           ['Marketing and Advertising', 'Modeling']        3.07       16.1
# 4          ['Celebrity', 'Actors', 'Comedy', 'Humor']        2.40       16.8
# 5                                 ['Art', 'Modeling']        0.20       17.2
# 6   ['Music', 'Singer', 'Celebrities', 'Film, Musi...        0.23       18.1
# 7   ['Marketing and Advertising', 'Lifestyle', 'Ac...        0.80       18.4
# 8                                 ['Comedy', 'Humor']        9.13       18.6
# 9                                          ['Actors']        6.90       19.0
# 10                                  ['Art', 'Actors']        0.30       18.8
# 11             ['Beauty', 'Art', 'Styling', 'Artist']        1.60       19.0
# 12  ['Actors', 'Celebrities', 'Animals & Pets', 'T...        0.63       19.3
# 13                             ['Art', 'Songwriting']        3.30       19.6
# 14                       ['Art', 'Surfing', 'Actors']        0.20       20.1
# 15                      ['Marketing and Advertising']        4.30       20.3
# 16                                          ['Humor']        0.50       21.4
# 17               ['Art', 'Singer', 'Actors', 'Music']        0.40       21.7
# 18    ['Celebrity', 'Actors', 'Celebrities', 'Humor']        0.18       21.7
# 19                                      ['Lifestyle']        1.00       22.1
# 20                                       ['Modeling']        1.00       22.4
# 21  ['Art', 'Modeling', 'Lifestyle', 'Celebrities'...        2.39       24.6
# 22                ['Celebrity', 'Modeling', 'Actors']        4.00       25.7
# 23                         ['Art', 'Music', 'Singer']        0.15       28.0
# 24                                         ['Artist']        0.80       33.8
# 25  ['Art', 'Modeling', 'Humor', 'Celebrities', 'F...        2.50       38.6
# 26            ['Celebrity', 'Art', 'Music', 'Actors']        0.20       45.7
# 27                               ['Actors', 'Artist']        0.40       53.0
# 28                ['Celebrity', 'Comedy', 'Comedian']        0.70       58.4
# 29                         ['Art', 'Music', 'Singer']        0.70       63.3

# %%
table_1.dtypes
# Out:
# ranking         int64
# username       object
# alias          object
# categories     object
# engagement    float64
# followers     float64
# dtype: object

# %%
table_1.set_index("ranking", inplace=True)
table_1
# Out:
#                       username                 alias  \
# ranking
# 1               @gessicakayane         gessicakayane
# 2               @andressasuita         andressasuita
# 3                    @leonardo              leonardo
# 4                       @taina                 taina
# 5                     @cocielo               cocielo
# 6                @jujusalimeni          jujusalimeni
# 7                        @lexa                  lexa
# 8             @flaviapavanelli       flaviapavanelli
# 9              @luvadepedreiro        luvadepedreiro
# 10                      @kjapa                 kjapa
# 11              @camilaqueiroz         camilaqueiroz
# 12                  @marimaria             marimaria
# 13                 @rafaavitti            rafaavitti
# 14             @zefelipecantor        zefelipecantor
# 15                 @caiocastro            caiocastro
# 16                    @mirella               mirella
# 17                  @tirullipa             tirullipa
# 18       @fernandasouzaoficial  fernandasouzaoficial
# 19             @brunogagliasso        brunogagliasso
# 20              @pefabiodemelo         pefabiodemelo
# 21               @rafakalimann          rafakalimann
# 22                   @viihtube              viihtube
# 23                  @gioewbank             gioewbank
# 24                    @kevinho               kevinho
# 25                   @juliette              juliette
# 26                   @virginia              virginia
# 27             @larissamanoela        larissamanoela
# 28                @tatawerneck           tatawerneck
# 29           @whinderssonnunes      whinderssonnunes
# 30                     @anitta                anitta
#
#                                                 categories  engagement  \
# ranking
# 1               ['Humor', 'Celebrities', 'Animals & Pets']        2.00
# 2        ['Modeling', 'Celebrities', 'Animals & Pets', ...        2.19
# 3                                                ['Music']        1.00
# 4                ['Marketing and Advertising', 'Modeling']        3.07
# 5               ['Celebrity', 'Actors', 'Comedy', 'Humor']        2.40
# 6                                      ['Art', 'Modeling']        0.20
# 7        ['Music', 'Singer', 'Celebrities', 'Film, Musi...        0.23
# 8        ['Marketing and Advertising', 'Lifestyle', 'Ac...        0.80
# 9                                      ['Comedy', 'Humor']        9.13
# 10                                              ['Actors']        6.90
# 11                                       ['Art', 'Actors']        0.30
# 12                  ['Beauty', 'Art', 'Styling', 'Artist']        1.60
# 13       ['Actors', 'Celebrities', 'Animals & Pets', 'T...        0.63
# 14                                  ['Art', 'Songwriting']        3.30
# 15                            ['Art', 'Surfing', 'Actors']        0.20
# 16                           ['Marketing and Advertising']        4.30
# 17                                               ['Humor']        0.50
# 18                    ['Art', 'Singer', 'Actors', 'Music']        0.40
# 19         ['Celebrity', 'Actors', 'Celebrities', 'Humor']        0.18
# 20                                           ['Lifestyle']        1.00
# 21                                            ['Modeling']        1.00
# 22       ['Art', 'Modeling', 'Lifestyle', 'Celebrities'...        2.39
# 23                     ['Celebrity', 'Modeling', 'Actors']        4.00
# 24                              ['Art', 'Music', 'Singer']        0.15
# 25                                              ['Artist']        0.80
# 26       ['Art', 'Modeling', 'Humor', 'Celebrities', 'F...        2.50
# 27                 ['Celebrity', 'Art', 'Music', 'Actors']        0.20
# 28                                    ['Actors', 'Artist']        0.40
# 29                     ['Celebrity', 'Comedy', 'Comedian']        0.70
# 30                              ['Art', 'Music', 'Singer']        0.70
#
#          followers
# ranking
# 1             15.2
# 2             15.7
# 3             15.9
# 4             16.1
# 5             16.8
# 6             17.2
# 7             18.1
# 8             18.4
# 9             18.6
# 10            19.0
# 11            18.8
# 12            19.0
# 13            19.3
# 14            19.6
# 15            20.1
# 16            20.3
# 17            21.4
# 18            21.7
# 19            21.7
# 20            22.1
# 21            22.4
# 22            24.6
# 23            25.7
# 24            28.0
# 25            33.8
# 26            38.6
# 27            45.7
# 28            53.0
# 29            58.4
# 30            63.3

# %%
table_1['followerss'] = 'Null'
table_1['following'] = 'Null'
table_1['post'] = 'Null'

# %%
table_1
# Out:
#                       username                 alias  \
# ranking
# 1               @gessicakayane         gessicakayane
# 2               @andressasuita         andressasuita
# 3                    @leonardo              leonardo
# 4                       @taina                 taina
# 5                     @cocielo               cocielo
# 6                @jujusalimeni          jujusalimeni
# 7                        @lexa                  lexa
# 8             @flaviapavanelli       flaviapavanelli
# 9              @luvadepedreiro        luvadepedreiro
# 10                      @kjapa                 kjapa
# 11              @camilaqueiroz         camilaqueiroz
# 12                  @marimaria             marimaria
# 13                 @rafaavitti            rafaavitti
# 14             @zefelipecantor        zefelipecantor
# 15                 @caiocastro            caiocastro
# 16                    @mirella               mirella
# 17                  @tirullipa             tirullipa
# 18       @fernandasouzaoficial  fernandasouzaoficial
# 19             @brunogagliasso        brunogagliasso
# 20              @pefabiodemelo         pefabiodemelo
# 21               @rafakalimann          rafakalimann
# 22                   @viihtube              viihtube
# 23                  @gioewbank             gioewbank
# 24                    @kevinho               kevinho
# 25                   @juliette              juliette
# 26                   @virginia              virginia
# 27             @larissamanoela        larissamanoela
# 28                @tatawerneck           tatawerneck
# 29           @whinderssonnunes      whinderssonnunes
# 30                     @anitta                anitta
#
#                                                 categories  engagement  \
# ranking
# 1               ['Humor', 'Celebrities', 'Animals & Pets']        2.00
# 2        ['Modeling', 'Celebrities', 'Animals & Pets', ...        2.19
# 3                                                ['Music']        1.00
# 4                ['Marketing and Advertising', 'Modeling']        3.07
# 5               ['Celebrity', 'Actors', 'Comedy', 'Humor']        2.40
# 6                                      ['Art', 'Modeling']        0.20
# 7        ['Music', 'Singer', 'Celebrities', 'Film, Musi...        0.23
# 8        ['Marketing and Advertising', 'Lifestyle', 'Ac...        0.80
# 9                                      ['Comedy', 'Humor']        9.13
# 10                                              ['Actors']        6.90
# 11                                       ['Art', 'Actors']        0.30
# 12                  ['Beauty', 'Art', 'Styling', 'Artist']        1.60
# 13       ['Actors', 'Celebrities', 'Animals & Pets', 'T...        0.63
# 14                                  ['Art', 'Songwriting']        3.30
# 15                            ['Art', 'Surfing', 'Actors']        0.20
# 16                           ['Marketing and Advertising']        4.30
# 17                                               ['Humor']        0.50
# 18                    ['Art', 'Singer', 'Actors', 'Music']        0.40
# 19         ['Celebrity', 'Actors', 'Celebrities', 'Humor']        0.18
# 20                                           ['Lifestyle']        1.00
# 21                                            ['Modeling']        1.00
# 22       ['Art', 'Modeling', 'Lifestyle', 'Celebrities'...        2.39
# 23                     ['Celebrity', 'Modeling', 'Actors']        4.00
# 24                              ['Art', 'Music', 'Singer']        0.15
# 25                                              ['Artist']        0.80
# 26       ['Art', 'Modeling', 'Humor', 'Celebrities', 'F...        2.50
# 27                 ['Celebrity', 'Art', 'Music', 'Actors']        0.20
# 28                                    ['Actors', 'Artist']        0.40
# 29                     ['Celebrity', 'Comedy', 'Comedian']        0.70
# 30                              ['Art', 'Music', 'Singer']        0.70
#
#          followers followerss following  post
# ranking
# 1             15.2       Null      Null  Null
# 2             15.7       Null      Null  Null
# 3             15.9       Null      Null  Null
# 4             16.1       Null      Null  Null
# 5             16.8       Null      Null  Null
# 6             17.2       Null      Null  Null
# 7             18.1       Null      Null  Null
# 8             18.4       Null      Null  Null
# 9             18.6       Null      Null  Null
# 10            19.0       Null      Null  Null
# 11            18.8       Null      Null  Null
# 12            19.0       Null      Null  Null
# 13            19.3       Null      Null  Null
# 14            19.6       Null      Null  Null
# 15            20.1       Null      Null  Null
# 16            20.3       Null      Null  Null
# 17            21.4       Null      Null  Null
# 18            21.7       Null      Null  Null
# 19            21.7       Null      Null  Null
# 20            22.1       Null      Null  Null
# 21            22.4       Null      Null  Null
# 22            24.6       Null      Null  Null
# 23            25.7       Null      Null  Null
# 24            28.0       Null      Null  Null
# 25            33.8       Null      Null  Null
# 26            38.6       Null      Null  Null
# 27            45.7       Null      Null  Null
# 28            53.0       Null      Null  Null
# 29            58.4       Null      Null  Null
# 30            63.3       Null      Null  Null

# %%
#function to scrape general information
def scrape_general_info(url):
    # instagram URL 
    URL = url

    # creating a dictionary 
    data = {} 

    # getting the request from url 
    r = requests.get(URL)

    # converting the text 
    s = BeautifulSoup(r.text, "html.parser") 

    # finding meta info 
    meta = s.find("meta", property ="og:description")

    #searching followers, followeing and number of posts info
    meta_2 = meta.attrs['content']
    meta_3 = meta_2.split("-")[0].split(" ")

    # assigning the values 
    data['Followers'] = meta_3[0] 
    data['Following'] = meta_3[2] 
    data['Posts'] = meta_3[4]
    
    return data

# %%
i = 0
for name in table_1['alias']:
    # user name 
    url = f"https://www.instagram.com/{name}/"

    # calling scrape function
    try:
        data = scrape_general_info(url)
        table_1.loc[i, 'followerss'] = data['Followers']
        table_1.loc[i, 'following'] = data['Following']
        table_1.loc[i, 'post'] = data['Posts']
        i += 1
    except:
        i += 1
        continue

# %%
table_1
# Out:
#                       username                 alias  \
# ranking
# 1               @gessicakayane         gessicakayane
# 2               @andressasuita         andressasuita
# 3                    @leonardo              leonardo
# 4                       @taina                 taina
# 5                     @cocielo               cocielo
# 6                @jujusalimeni          jujusalimeni
# 7                        @lexa                  lexa
# 8             @flaviapavanelli       flaviapavanelli
# 9              @luvadepedreiro        luvadepedreiro
# 10                      @kjapa                 kjapa
# 11              @camilaqueiroz         camilaqueiroz
# 12                  @marimaria             marimaria
# 13                 @rafaavitti            rafaavitti
# 14             @zefelipecantor        zefelipecantor
# 15                 @caiocastro            caiocastro
# 16                    @mirella               mirella
# 17                  @tirullipa             tirullipa
# 18       @fernandasouzaoficial  fernandasouzaoficial
# 19             @brunogagliasso        brunogagliasso
# 20              @pefabiodemelo         pefabiodemelo
# 21               @rafakalimann          rafakalimann
# 22                   @viihtube              viihtube
# 23                  @gioewbank             gioewbank
# 24                    @kevinho               kevinho
# 25                   @juliette              juliette
# 26                   @virginia              virginia
# 27             @larissamanoela        larissamanoela
# 28                @tatawerneck           tatawerneck
# 29           @whinderssonnunes      whinderssonnunes
# 30                     @anitta                anitta
# 0                          NaN                   NaN
#
#                                                 categories  engagement  \
# ranking
# 1               ['Humor', 'Celebrities', 'Animals & Pets']        2.00
# 2        ['Modeling', 'Celebrities', 'Animals & Pets', ...        2.19
# 3                                                ['Music']        1.00
# 4                ['Marketing and Advertising', 'Modeling']        3.07
# 5               ['Celebrity', 'Actors', 'Comedy', 'Humor']        2.40
# 6                                      ['Art', 'Modeling']        0.20
# 7        ['Music', 'Singer', 'Celebrities', 'Film, Musi...        0.23
# 8        ['Marketing and Advertising', 'Lifestyle', 'Ac...        0.80
# 9                                      ['Comedy', 'Humor']        9.13
# 10                                              ['Actors']        6.90
# 11                                       ['Art', 'Actors']        0.30
# 12                  ['Beauty', 'Art', 'Styling', 'Artist']        1.60
# 13       ['Actors', 'Celebrities', 'Animals & Pets', 'T...        0.63
# 14                                  ['Art', 'Songwriting']        3.30
# 15                            ['Art', 'Surfing', 'Actors']        0.20
# 16                           ['Marketing and Advertising']        4.30
# 17                                               ['Humor']        0.50
# 18                    ['Art', 'Singer', 'Actors', 'Music']        0.40
# 19         ['Celebrity', 'Actors', 'Celebrities', 'Humor']        0.18
# 20                                           ['Lifestyle']        1.00
# 21                                            ['Modeling']        1.00
# 22       ['Art', 'Modeling', 'Lifestyle', 'Celebrities'...        2.39
# 23                     ['Celebrity', 'Modeling', 'Actors']        4.00
# 24                              ['Art', 'Music', 'Singer']        0.15
# 25                                              ['Artist']        0.80
# 26       ['Art', 'Modeling', 'Humor', 'Celebrities', 'F...        2.50
# 27                 ['Celebrity', 'Art', 'Music', 'Actors']        0.20
# 28                                    ['Actors', 'Artist']        0.40
# 29                     ['Celebrity', 'Comedy', 'Comedian']        0.70
# 30                              ['Art', 'Music', 'Singer']        0.70
# 0                                                      NaN         NaN
#
#          followers followerss following   post
# ranking
# 1             15.2        16M     1,862  3,454
# 2             15.7        18M       152  2,295
# 3             15.9        17M     2,011    967
# 4             16.1        20M     1,941  1,926
# 5             16.8        19M     1,063  9,753
# 6             17.2        19M     1,353  7,940
# 7             18.1        20M     1,215  3,154
# 8             18.4        20M       347     15
# 9             18.6        19M       562     24
# 10            19.0        21M     1,118  1,952
# 11            18.8        21M     1,109  3,243
# 12            19.0        21M     2,329  2,981
# 13            19.3        26M       759  1,031
# 14            19.6        21M       594  2,104
# 15            20.1        27M     1,562    817
# 16            20.3        30M     1,477    10K
# 17            21.4        22M     1,927  6,137
# 18            21.7        22M     4,326  6,146
# 19            21.7        27M       658  6,312
# 20            22.1        23M     3,342  1,558
# 21            22.4        26M     1,348  3,325
# 22            24.6        31M     2,185  7,089
# 23            25.7        29M     1,033    481
# 24            28.0        33M     1,915  1,090
# 25            33.8        42M       442  1,944
# 26            38.6        50M     2,666  5,390
# 27            45.7        57M     2,488  5,637
# 28            53.0        61M     1,892  2,787
# 29            58.4        66M     3,061  5,205
# 30            63.3       Null      Null   Null
# 0              NaN        21M       894  2,821
